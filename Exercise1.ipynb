# %%
ice_cream_rating=9
sleeping_rating=8

# %%
first_name='Summer'
last_name='Applegate'
my_name='Summer Applegate'

# %%
happiness_rating= (ice_cream_rating+sleeping_rating)/2

# %%
print(happiness_rating)
# Out:
# 8.5

# %%
print(type(ice_cream_rating),type(first_name),type(happiness_rating))
# Out:
# <class 'int'> <class 'str'> <class 'float'>

# %% [markdown]
# All of the data types do not make sense.
# Why are ice_cream_rating and happiness_rating different data
# types (int vs. float), when they are both integers?
# Actually, nvm. ice_cream is a whole number, while happiness is
# a decimal. That's why.

# %%
my_name='Summer Applegate'
print(my_name)
# Out:
# Summer Applegate

# %%
print('My name is', my_name)
# Out:
# My name is Summer Applegate

# %%
first_name='Summer'
ice_cream_rating=9
sleeping_rating=8
happiness_rating= (ice_cream_rating+sleeping_rating)/2
print('My name is', first_name, 
'and I give eating ice cream a score of', ice_cream_rating, 
'out of 10. I am', first_name, 'and my sleeping enjoyment rating is',sleeping_rating,'/ 10. Based on the factors above, my happiness score is',
happiness_rating, 'out of 10, or', happiness_rating*10, '%.')
# Out:
# My name is Summer and I give eating ice cream a score of 9 out of 10. I am Summer and my sleeping enjoyment rating is 8 / 10. Based on the factors above, my happiness score is 8.5 out of 10, or 85.0 %.
